# %%
import requests
import csv
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from google.colab import drive

# %%
def get_html(url):
    return urlopen(url)
def get_soup(html):
    return BeautifulSoup(html, 'html.parser')


def get_wikipedia_tables(url):
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    tables = soup.find_all('table')
    return tables

# %%
def extract_person_data(cells):
    if len(cells) > 1:
        person = cells[0]
        name = person.text.strip()
        url = person.a['href'] if person.a else ''
        return name, url
    return None, None

# %%
def get_wikidata_id(text_id):
    json_html = f'https://en.wikipedia.org/w/api.php?action=query&prop=pageprops&titles={text_id}&format=json'
    headers = {'Accept': 'application/json'}

    try:
        response = requests.get(json_html, headers=headers).json()
        if response.get('query'):
            for key, page in response['query']['pages'].items():
                wikibase_item = page.get('pageprops', {}).get('wikibase_item', '')
                if wikibase_item:
                    return wikibase_item
    except:
        pass

    return None

# %%
def is_dinner_party_member(api_response, wikibase):
    claims = api_response.get('entities', {}).get(wikibase, {}).get('claims', {})
    part_of = claims.get('P361', [])
    depicted_by = claims.get('P1299', [])

    for index in part_of + depicted_by:
        if index.get('mainsnak', {}).get('datavalue', {}).get('value', {}).get('id') == 'Q2915473':
            return True

    return False

# %%
def process_tables(tables):
    data_urls = []
    wikidata_ids = []  # Declare an empty list
    csv_file = 'Dinner_Party.csv'

    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=['name', 'url', 'status'])
        writer.writeheader()

        for table in tables:
            process_table_rows(table, writer, data_urls, wikidata_ids)

    return data_urls

# %%
def process_table_rows(table, writer, data_urls, wikidata_ids, manual_check):
    rows = table.find_all('tr')
    error_no_name = "Error encountered"
    for index, row in enumerate(rows):
        rows_left = len(rows) - index - 1
        if index == 0:  # Skip the header row
            continue
        cells = row.find_all('td')
        name, url = extract_person_data(cells)
        if name and url:
            text_id = url.split("/")[-1]
            wikibase_item = get_wikidata_id(text_id)
            if wikibase_item:
                data_html = f'https://www.wikidata.org/wiki/{wikibase_item}'  # Fixed variable name
                data_json_html = f'https://www.wikidata.org/w/api.php?action=wbgetentities&ids={wikibase_item}&format=json'  # Fixed variable name
                api_response = requests.get(data_json_html).json()
                if is_dinner_party_member(api_response, wikibase_item):
                    status = f'{name} is a Dinner Party member. {rows_left} item{"s" if rows_left != 1 else ""} to add'
                else:
                    status = f'{name} needs Dinner Party added to their Wikidata. {rows_left} items to add'
                writer.writerow({'name': name, 'url': data_html, 'status': status})
            else:
                status = f'Error encountered with {name}. Check manually. {rows_left} items to review.'
                manual_check.append({'name': name, 'url': url})
        else:
            status = error_no_name
        if name:
            print(status)
        else:
            print(f"Error encountered. {rows_left} items to review.")

# %%
def save_to_csv(data_urls, csv_path):
    header = ['name', 'url', 'status']
    df = pd.DataFrame(data_urls, columns=header)
    df.to_csv(csv_path, encoding='utf-8-sig', index=False)

    drive.mount('/content/drive', force_remount=True)
    path = '/content/drive/My Drive/output.csv'
    with open(path, 'w', encoding = 'utf-8-sig') as f:
      df.to_csv(f)

# %%
def read_csv(csv_path):
    return pd.read_csv(csv_path)

# %%
def save_output_csv(df, output_csv_path):
    df.to_csv(output_csv_path, encoding='utf-8-sig', index=False)

# %%
def main():
    url = 'https://en.wikipedia.org/wiki/List_of_women_in_the_Heritage_Floor'
    html = get_html(url)
    soup = get_soup(html)
    tables = get_wikipedia_tables(url)
    data_urls = []
    manual_check = []
    wikidata_ids = []  # Declare an empty list
    csv_file = 'Dinner_Party.csv'

    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=['name', 'url', 'status'])
        writer.writeheader()

        for table in tables:
            process_table_rows(table, writer, data_urls, wikidata_ids, manual_check)

    # Save data_urls to CSV
    save_to_csv(data_urls, csv_file)

    # Print manual check items
    for item in manual_check:
        print(f"Manual check required for: {item['name']} - URL: {item['url']}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Abella of Salerno is a Dinner Party member. 995 items to add
# Abigail is a Dinner Party member. 994 items to add
# Abigail Adams is a Dinner Party member. 993 items to add
# Error encountered with Adela of Blois. Check manually. 992 items to review.
# Error encountered with Adela Zamudio-Ribero. Check manually. 991 items to review.
# Adelaide is a Dinner Party member. 990 items to add
# Adelaide Labille-Guiard is a Dinner Party member. 989 items to add
# Adelaide of Susa is a Dinner Party member. 988 items to add
# Adelberger is a Dinner Party member. 987 items to add
# Adelheid Popp is a Dinner Party member. 986 items to add
# Eudocia is a Dinner Party member. 985 items to add
# Eudoxia is a Dinner Party member. 984 items to add
# Error encountered with Aemilia. Check manually. 983 items to review.
# Æthelburg needs Dinner Party added to their Wikidata. 982 items to add
# Ethelberga needs Dinner Party added to their Wikidata. 981 items to add
# Æthelflæd is a Dinner Party member. 980 items to add
# Agatha needs Dinner Party added to their Wikidata. 979 items to add
# Ageltrude Benevento needs Dinner Party added to their Wikidata. 978 items to add
# Aglaonice needs Dinner Party added to their Wikidata. 977 items to add
# Agnes d'Harcourt needs Dinner Party added to their Wikidata. 976 items to add
# Agnes needs Dinner Party added to their Wikidata. 975 items to add
# Agnes needs Dinner Party added to their Wikidata. 974 items to add
# Agnes of Poitou needs Dinner Party added to their Wikidata. 973 items to add
# Error encountered with Agnes of Dunbar. Check manually. 972 items to review.
# Agnes Sampson needs Dinner Party added to their Wikidata. 971 items to add
# Agnes Smedley needs Dinner Party added to their Wikidata. 970 items to add
# Agnès Sorel needs Dinner Party added to their Wikidata. 969 items to add
# Agnes Waterhouse needs Dinner Party added to their Wikidata. 968 items to add
# Agnodice needs Dinner Party added to their Wikidata. 967 items to add
# Agrippina I needs Dinner Party added to their Wikidata. 966 items to add
# Agrippina II needs Dinner Party added to their Wikidata. 965 items to add
# Aisha needs Dinner Party added to their Wikidata. 964 items to add
# Error encountered with Ajysyt. Check manually. 963 items to review.
# Albertine Necker de Saussure needs Dinner Party added to their Wikidata. 962 items to add
# Error encountered with Aleksandra Kollantay. Check manually. 961 items to review.
# Alessandra Giliani needs Dinner Party added to their Wikidata. 960 items to add
# Aletta Jacobs needs Dinner Party added to their Wikidata. 959 items to add
# Error encountered with Alexandra of Jerusalem. Check manually. 958 items to review.
# Error encountered with Alexandra van Grippenberg. Check manually. 957 items to review.
# Alfonsina Storni needs Dinner Party added to their Wikidata. 956 items to add
# Alice Kyteler needs Dinner Party added to their Wikidata. 955 items to add
# Alice Milliat needs Dinner Party added to their Wikidata. 954 items to add
# Alice Paul needs Dinner Party added to their Wikidata. 953 items to add
# Alice Pike Barney needs Dinner Party added to their Wikidata. 952 items to add
# Error encountered with Alice Samuel. Check manually. 951 items to review.
# Alice Stone Blackwell needs Dinner Party added to their Wikidata. 950 items to add
# Aliénor de Poitiers needs Dinner Party added to their Wikidata. 949 items to add
# Error encountered with Alison Rutherford. Check manually. 948 items to review.
# Almucs de Castelnau needs Dinner Party added to their Wikidata. 947 items to add
# Aloara needs Dinner Party added to their Wikidata. 946 items to add
# Alpis de Cudot needs Dinner Party added to their Wikidata. 945 items to add
# Althea Gibson needs Dinner Party added to their Wikidata. 944 items to add
# Alukah needs Dinner Party added to their Wikidata. 943 items to add
# Amat-Mamu needs Dinner Party added to their Wikidata. 942 items to add
# Amelia Earhart needs Dinner Party added to their Wikidata. 941 items to add
# Amelia Holst needs Dinner Party added to their Wikidata. 940 items to add
# Error encountered with Amelia Villa. Check manually. 939 items to review.
# Amy Beach needs Dinner Party added to their Wikidata. 938 items to add
# Ana Betancourt needs Dinner Party added to their Wikidata. 937 items to add
# Anaconda needs Dinner Party added to their Wikidata. 936 items to add
# Anahita needs Dinner Party added to their Wikidata. 935 items to add
# Anaïs Nin needs Dinner Party added to their Wikidata. 934 items to add
# Anastasia needs Dinner Party added to their Wikidata. 933 items to add
# Anastasia needs Dinner Party added to their Wikidata. 932 items to add
# Error encountered with Anath. Check manually. 931 items to review.
# Anasandra needs Dinner Party added to their Wikidata. 930 items to add
# Andrea Villarreal needs Dinner Party added to their Wikidata. 929 items to add
# Angela Merici needs Dinner Party added to their Wikidata. 928 items to add
# Error encountered with Angelberga. Check manually. 927 items to review.
# Angéle de la Barthe needs Dinner Party added to their Wikidata. 926 items to add
# Angelica Balabanoff needs Dinner Party added to their Wikidata. 925 items to add
# Angelica Kauffman needs Dinner Party added to their Wikidata. 924 items to add
# Angelina Grimké needs Dinner Party added to their Wikidata. 923 items to add
# Error encountered with Angelique du Coudray. Check manually. 922 items to review.
# Anna Amalia needs Dinner Party added to their Wikidata. 921 items to add
# Ann Lee needs Dinner Party added to their Wikidata. 920 items to add
# Error encountered with Anna Dalassena Comnena. Check manually. 919 items to review.
# Error encountered with Anna Karsch. Check manually. 918 items to review.
# Anna Comnena needs Dinner Party added to their Wikidata. 917 items to add
# Anna Maria Schwagel needs Dinner Party added to their Wikidata. 916 items to add
# Anna Manzolini needs Dinner Party added to their Wikidata. 915 items to add
# Anna Pavlova needs Dinner Party added to their Wikidata. 914 items to add
# Anna Schabanoff needs Dinner Party added to their Wikidata. 913 items to add
# Anna Sophia needs Dinner Party added to their Wikidata. 912 items to add
# Error encountered with Annabella Drummond. Check manually. 911 items to review.
# Anne Askew needs Dinner Party added to their Wikidata. 910 items to add
# Anne Bacon needs Dinner Party added to their Wikidata. 909 items to add
# Error encountered with Anne Baynard. Check manually. 908 items to review.
# Error encountered with Anne Bonney. Check manually. 907 items to review.
# Anne Bradstreet needs Dinner Party added to their Wikidata. 906 items to add
# Anne Clough needs Dinner Party added to their Wikidata. 905 items to add
# Anne Dacier needs Dinner Party added to their Wikidata. 904 items to add
# Anne Ella Carroll needs Dinner Party added to their Wikidata. 903 items to add
# Anne Halkett needs Dinner Party added to their Wikidata. 902 items to add
# Error encountered with Anne of Beaujeu. Check manually. 901 items to review.
# Anna needs Dinner Party added to their Wikidata. 900 items to add
# Anne of Brittany needs Dinner Party added to their Wikidata. 899 items to add
# Error encountered with Anne Redfearne. Check manually. 898 items to review.
# Annie Jump Cannon is a Dinner Party member. 897 items to add
# Annie Kenney needs Dinner Party added to their Wikidata. 896 items to add
# Annie Smith Peck needs Dinner Party added to their Wikidata. 895 items to add
# Error encountered with Annie Wood Besant. Check manually. 894 items to review.
# Antigone needs Dinner Party added to their Wikidata. 893 items to add
# Antiope needs Dinner Party added to their Wikidata. 892 items to add
# Antonia Brico needs Dinner Party added to their Wikidata. 891 items to add
# Error encountered with Antonia Padoani Bembo. Check manually. 890 items to review.
# Amyte needs Dinner Party added to their Wikidata. 889 items to add
# Aphra Behn needs Dinner Party added to their Wikidata. 888 items to add
# Aphrodite needs Dinner Party added to their Wikidata. 887 items to add
# Arachne needs Dinner Party added to their Wikidata. 886 items to add
# Aretaphila of Cyrene needs Dinner Party added to their Wikidata. 885 items to add
# Arete of Cyrene needs Dinner Party added to their Wikidata. 884 items to add
# Ariadne needs Dinner Party added to their Wikidata. 883 items to add
# Arianrhod needs Dinner Party added to their Wikidata. 882 items to add
# Arinitti needs Dinner Party added to their Wikidata. 881 items to add
# Error encountered with Aristoclea. Check manually. 880 items to review.
# Arsinoe II needs Dinner Party added to their Wikidata. 879 items to add
# Artemis needs Dinner Party added to their Wikidata. 878 items to add
# Error encountered with Artemisia I. Check manually. 877 items to review.
# Error encountered with Artemisia II. Check manually. 876 items to review.
# Asherah needs Dinner Party added to their Wikidata. 875 items to add
# Error encountered with Ashtoreth. Check manually. 874 items to review.
# Aspasia of Athens is a Dinner Party member. 873 items to add
# Astarte needs Dinner Party added to their Wikidata. 872 items to add
# Atalanta needs Dinner Party added to their Wikidata. 871 items to add
# Athaliah needs Dinner Party added to their Wikidata. 870 items to add
# Athanarsa needs Dinner Party added to their Wikidata. 869 items to add
# Athene needs Dinner Party added to their Wikidata. 868 items to add
# Atira needs Dinner Party added to their Wikidata. 867 items to add
# Error encountered with Augusta Fickert. Check manually. 866 items to review.
# Augusta Savage needs Dinner Party added to their Wikidata. 865 items to add
# Error encountered with Augusta Schmidt. Check manually. 864 items to review.
# Error encountered with Augustina Saragossa. Check manually. 863 items to review.
# Awashonks needs Dinner Party added to their Wikidata. 862 items to add
# Error encountered with Axiothea. Check manually. 861 items to review.
# Error encountered with Baba Petkova. Check manually. 860 items to review.
# Error encountered with Babe Didrikson. Check manually. 859 items to review.
# Error encountered with Baptista Malatesta. Check manually. 858 items to review.
# Baranamtarra needs Dinner Party added to their Wikidata. 857 items to add
# Barbara Bodichon needs Dinner Party added to their Wikidata. 856 items to add
# Barbara Hepworth needs Dinner Party added to their Wikidata. 855 items to add
# Barbara Strozzi needs Dinner Party added to their Wikidata. 854 items to add
# Barbara Uttman is a Dinner Party member. 853 items to add
# Barbe de Verrue needs Dinner Party added to their Wikidata. 852 items to add
# Error encountered with Baroness de Beausoleil. Check manually. 851 items to review.
# Basilea needs Dinner Party added to their Wikidata. 850 items to add
# Error encountered with Basine. Check manually. 849 items to review.
# Bathilde needs Dinner Party added to their Wikidata. 848 items to add
# Bathsua Makin needs Dinner Party added to their Wikidata. 847 items to add
# Error encountered with Baudonivia. Check manually. 846 items to review.
# Error encountered with Beatrice de Die. Check manually. 845 items to review.
# Beatrice Webb needs Dinner Party added to their Wikidata. 844 items to add
# Error encountered with Beatrix Galindo. Check manually. 843 items to review.
# Begga needs Dinner Party added to their Wikidata. 842 items to add
# Error encountered with Bel-Shalti-Narrar. Check manually. 841 items to review.
# Error encountered with Belva Lockwood. Check manually. 840 items to review.
# Berenguela needs Dinner Party added to their Wikidata. 839 items to add
# Error encountered with Bernarda de la Cerda. Check manually. 838 items to review.
# Bertha Lutz needs Dinner Party added to their Wikidata. 837 items to add
# Error encountered with Bertha of England. Check manually. 836 items to review.
# Bertha of Sulzbach needs Dinner Party added to their Wikidata. 835 items to add
# Bertha von Suttner needs Dinner Party added to their Wikidata. 834 items to add
# Error encountered with Bertha of France. Check manually. 833 items to review.
# Berthe Morisot needs Dinner Party added to their Wikidata. 832 items to add
# Error encountered with Berthildis. Check manually. 831 items to review.
# Error encountered with Bertille. Check manually. 830 items to review.
# Bertha needs Dinner Party added to their Wikidata. 829 items to add
# Elizabeth Talbot needs Dinner Party added to their Wikidata. 828 items to add
# Bessie Smith needs Dinner Party added to their Wikidata. 827 items to add
# Error encountered with Betsy Kjelsberg. Check manually. 826 items to review.
# Bettina von Arnim needs Dinner Party added to their Wikidata. 825 items to add
# Bettisia Gozzadini needs Dinner Party added to their Wikidata. 824 items to add
# Blanche of Castile needs Dinner Party added to their Wikidata. 823 items to add
# Blandina needs Dinner Party added to their Wikidata. 822 items to add
# Blodeuwedd needs Dinner Party added to their Wikidata. 821 items to add
# Error encountered with Bona-Dea. Check manually. 820 items to review.
# Error encountered with Bourgot. Check manually. 819 items to review.
# Bridget Bevan needs Dinner Party added to their Wikidata. 818 items to add
# Birgitta needs Dinner Party added to their Wikidata. 817 items to add
# Bridget Tott needs Dinner Party added to their Wikidata. 816 items to add
# Brigh Brigaid needs Dinner Party added to their Wikidata. 815 items to add
# Brigid needs Dinner Party added to their Wikidata. 814 items to add
# Britomartis needs Dinner Party added to their Wikidata. 813 items to add
# Brunhilde needs Dinner Party added to their Wikidata. 812 items to add
# Beruiah needs Dinner Party added to their Wikidata. 811 items to add
# Error encountered with Brynhild. Check manually. 810 items to review.
# Buto needs Dinner Party added to their Wikidata. 809 items to add
# Caelia Macrina needs Dinner Party added to their Wikidata. 808 items to add
# Cambra needs Dinner Party added to their Wikidata. 807 items to add
# Camilla needs Dinner Party added to their Wikidata. 806 items to add
# Candelaria Figueredo needs Dinner Party added to their Wikidata. 805 items to add
# Capillana needs Dinner Party added to their Wikidata. 804 items to add
# Lady Carcas needs Dinner Party added to their Wikidata. 803 items to add
# Cardea needs Dinner Party added to their Wikidata. 802 items to add
# Carlota Matienzo needs Dinner Party added to their Wikidata. 801 items to add
# Carlotta Ferrari needs Dinner Party added to their Wikidata. 800 items to add
# Carmenta needs Dinner Party added to their Wikidata. 799 items to add
# Caroline Norton needs Dinner Party added to their Wikidata. 798 items to add
# Error encountered with Caroline Schlegel. Check manually. 797 items to review.
# Carrie Chapman Catt needs Dinner Party added to their Wikidata. 796 items to add
# Carrie Nation needs Dinner Party added to their Wikidata. 795 items to add
# Error encountered with Cartismandua. Check manually. 794 items to review.
# Error encountered with Cassandra Fidelis. Check manually. 793 items to review.
# Cassandra needs Dinner Party added to their Wikidata. 792 items to add
# Error encountered with Caterina Cornaro. Check manually. 791 items to review.
# Error encountered with Caterina Sforzia. Check manually. 790 items to review.
# Error encountered with Caterina van Hemessen. Check manually. 789 items to review.
# Catharine Fisher needs Dinner Party added to their Wikidata. 788 items to add
# Error encountered with Catherine Beecher. Check manually. 787 items to review.
# Error encountered with Catherine de Rambouillet. Check manually. 786 items to review.
# Error encountered with Catherine Deshayes. Check manually. 785 items to review.
# Error encountered with Catherine Greene. Check manually. 784 items to review.
# Catherine needs Dinner Party added to their Wikidata. 783 items to add
# Catherine of Aragon needs Dinner Party added to their Wikidata. 782 items to add
# Catherine Adorni needs Dinner Party added to their Wikidata. 781 items to add
# Catherine of Siena needs Dinner Party added to their Wikidata. 780 items to add
# Catherine Pavlovna needs Dinner Party added to their Wikidata. 779 items to add
# Catherine II (The Great) needs Dinner Party added to their Wikidata. 778 items to add
# Celia Fiennes needs Dinner Party added to their Wikidata. 777 items to add
# Cerridwen needs Dinner Party added to their Wikidata. 776 items to add
# Caritas Pirckheimer needs Dinner Party added to their Wikidata. 775 items to add
# Charlotte Brontë needs Dinner Party added to their Wikidata. 774 items to add
# Charlotte Corday needs Dinner Party added to their Wikidata. 773 items to add
# Charlotte Guest needs Dinner Party added to their Wikidata. 772 items to add
# Charlotte Perkins Gilman needs Dinner Party added to their Wikidata. 771 items to add
# Error encountered with Chicomecoatl. Check manually. 770 items to review.
# Chiomara needs Dinner Party added to their Wikidata. 769 items to add
# Christabel Pankhurst needs Dinner Party added to their Wikidata. 768 items to add
# Error encountered with Christina of Sweden. Check manually. 767 items to review.
# Christina Rossetti needs Dinner Party added to their Wikidata. 766 items to add
# Circe needs Dinner Party added to their Wikidata. 765 items to add
# Clara Barton needs Dinner Party added to their Wikidata. 764 items to add
# Error encountered with Clara Hatzerlin. Check manually. 763 items to review.
# Clara Schumann needs Dinner Party added to their Wikidata. 762 items to add
# Clara Zetkin needs Dinner Party added to their Wikidata. 761 items to add
# Clare of Assisi needs Dinner Party added to their Wikidata. 760 items to add
# Claricia needs Dinner Party added to their Wikidata. 759 items to add
# Error encountered with Claudine de Tencin. Check manually. 758 items to review.
# Clémence Royer needs Dinner Party added to their Wikidata. 757 items to add
# Error encountered with Cleobuline. Check manually. 756 items to review.
# Cleopatra needs Dinner Party added to their Wikidata. 755 items to add
# Error encountered with Clodia. Check manually. 754 items to review.
# Clotilda needs Dinner Party added to their Wikidata. 753 items to add
# Clytemnestra needs Dinner Party added to their Wikidata. 752 items to add
# Error encountered with Coatlicue. Check manually. 751 items to review.
# Error encountered with Cobhlair Mor. Check manually. 750 items to review.
# Colette needs Dinner Party added to their Wikidata. 749 items to add
# Error encountered with Constance Lytton. Check manually. 748 items to review.
# Constantia needs Dinner Party added to their Wikidata. 747 items to add
# Error encountered with Corinna of Tanagra. Check manually. 746 items to review.
# Error encountered with Cornelia. Check manually. 745 items to review.
# Cornelia needs Dinner Party added to their Wikidata. 744 items to add
# Cresilla needs Dinner Party added to their Wikidata. 743 items to add
# Error encountered with Cristina Trivulzio. Check manually. 742 items to review.
# Sibyl of Cumae needs Dinner Party added to their Wikidata. 741 items to add
# Error encountered with Cunegund. Check manually. 740 items to review.
# Cybele needs Dinner Party added to their Wikidata. 739 items to add
# Cynane needs Dinner Party added to their Wikidata. 738 items to add
# Cynisca needs Dinner Party added to their Wikidata. 737 items to add
# Damo needs Dinner Party added to their Wikidata. 736 items to add
# Danielis needs Dinner Party added to their Wikidata. 735 items to add
# Danu (Irish goddess) needs Dinner Party added to their Wikidata. 734 items to add
# Daphne needs Dinner Party added to their Wikidata. 733 items to add
# Deborah Sampson needs Dinner Party added to their Wikidata. 732 items to add
# Deborah needs Dinner Party added to their Wikidata. 731 items to add
# Demeter needs Dinner Party added to their Wikidata. 730 items to add
# Error encountered with Dervorguilla. Check manually. 729 items to review.
# Dhuoda needs Dinner Party added to their Wikidata. 728 items to add
# Dido needs Dinner Party added to their Wikidata. 727 items to add
# Error encountered with Diemud. Check manually. 726 items to review.
# Diotima needs Dinner Party added to their Wikidata. 725 items to add
# Djuna Barnes needs Dinner Party added to their Wikidata. 724 items to add
# Dolores Ibárruri needs Dinner Party added to their Wikidata. 723 items to add
# Dorcas needs Dinner Party added to their Wikidata. 722 items to add
# Doris Lessing needs Dinner Party added to their Wikidata. 721 items to add
# Dorotea Bucca needs Dinner Party added to their Wikidata. 720 items to add
# Dorothea Dix needs Dinner Party added to their Wikidata. 719 items to add
# Dorothea Lange needs Dinner Party added to their Wikidata. 718 items to add
# Error encountered with Dorothea Leporin-Erxleben. Check manually. 717 items to review.
# Error encountered with Dorothea von Rodde. Check manually. 716 items to review.
# Dorothy Arzner needs Dinner Party added to their Wikidata. 715 items to add
# Dorothy Richardson needs Dinner Party added to their Wikidata. 714 items to add
# Dorothy Wordsworth needs Dinner Party added to their Wikidata. 713 items to add
# Error encountered with Douceline de Digne. Check manually. 712 items to review.
# Eachtach needs Dinner Party added to their Wikidata. 711 items to add
# Error encountered with Eadburga. Check manually. 710 items to review.
# Eanswith needs Dinner Party added to their Wikidata. 709 items to add
# Ebba needs Dinner Party added to their Wikidata. 708 items to add
# Edith Cavell needs Dinner Party added to their Wikidata. 707 items to add
# Edith Evans needs Dinner Party added to their Wikidata. 706 items to add
# Edith needs Dinner Party added to their Wikidata. 705 items to add
# Edith Sitwell needs Dinner Party added to their Wikidata. 704 items to add
# Edith Wharton needs Dinner Party added to their Wikidata. 703 items to add
# Edmonia Lewis needs Dinner Party added to their Wikidata. 702 items to add
# Edna St. Vincent Millay needs Dinner Party added to their Wikidata. 701 items to add
# Error encountered with Egee. Check manually. 700 items to review.
# Ehyophsta needs Dinner Party added to their Wikidata. 699 items to add
# Eileen Gray needs Dinner Party added to their Wikidata. 698 items to add
# Eleanor Roosevelt needs Dinner Party added to their Wikidata. 697 items to add
# Eleonora Duse needs Dinner Party added to their Wikidata. 696 items to add
# Error encountered with Elfrida Andree. Check manually. 695 items to review.
# Elin Kallio needs Dinner Party added to their Wikidata. 694 items to add
# Error encountered with Elisabeth de La Guerre. Check manually. 693 items to review.
# Error encountered with Élisabeth Vigée-Lebrun. Check manually. 692 items to review.
# Elisabetta Gonzaga needs Dinner Party added to their Wikidata. 691 items to add
# Elisabetta Sirani needs Dinner Party added to their Wikidata. 690 items to add
# Eliška Krásnohorská needs Dinner Party added to their Wikidata. 689 items to add
# Error encountered with Eliza Lucas Pinckney. Check manually. 688 items to review.
# Elizabeth Barrett Browning needs Dinner Party added to their Wikidata. 687 items to add
# Error encountered with Elizabeth Bekker. Check manually. 686 items to review.
# Elizabeth Cady Stanton needs Dinner Party added to their Wikidata. 685 items to add
# Elizabeth Carter needs Dinner Party added to their Wikidata. 684 items to add
# Elizabeth Cellier needs Dinner Party added to their Wikidata. 683 items to add
# Error encountered with Elizabeth Cheron. Check manually. 682 items to review.
# Error encountered with Elizabeth Danviers. Check manually. 681 items to review.
# Error encountered with Elizabeth Druzbacka. Check manually. 680 items to review.
# Elizabeth Farren is a Dinner Party member. 679 items to add
# Elizabeth Fry needs Dinner Party added to their Wikidata. 678 items to add
# Elizabeth Garrett Anderson needs Dinner Party added to their Wikidata. 677 items to add
# Elizabeth Gurley Flynn needs Dinner Party added to their Wikidata. 676 items to add
# Elizabeth Hamilton needs Dinner Party added to their Wikidata. 675 items to add
# Error encountered with Elizabeth Hoby. Check manually. 674 items to review.
# Jane Weston needs Dinner Party added to their Wikidata. 673 items to add
# Elizabeth Lucar needs Dinner Party added to their Wikidata. 672 items to add
# Elizabeth Montagu needs Dinner Party added to their Wikidata. 671 items to add
# Error encountered with Elizabeth Ney. Check manually. 670 items to review.
# Elizabeth needs Dinner Party added to their Wikidata. 669 items to add
# Error encountered with Elizabeth of Schönau. Check manually. 668 items to review.
# Error encountered with Elizabeth Petrovna. Check manually. 667 items to review.
# Error encountered with Elizabeth Southern. Check manually. 666 items to review.
# Error encountered with Elizabeth Stagel. Check manually. 665 items to review.
# Elizabeth Vesey needs Dinner Party added to their Wikidata. 664 items to add
# Error encountered with Ellen Richards. Check manually. 663 items to review.
# Elpinice needs Dinner Party added to their Wikidata. 662 items to add
# Error encountered with Emilia Pardo-Bazán. Check manually. 661 items to review.
# Error encountered with Emilie du Chatelet. Check manually. 660 items to review.
# Emilie Snethlage needs Dinner Party added to their Wikidata. 659 items to add
# Emily Blackwell needs Dinner Party added to their Wikidata. 658 items to add
# Emily Brontë needs Dinner Party added to their Wikidata. 657 items to add
# Emily Carr needs Dinner Party added to their Wikidata. 656 items to add
# Emily Faithfull needs Dinner Party added to their Wikidata. 655 items to add
# Emma Goldman needs Dinner Party added to their Wikidata. 654 items to add
# Emma Paterson needs Dinner Party added to their Wikidata. 653 items to add
# Emma Willard needs Dinner Party added to their Wikidata. 652 items to add
# Emmeline Pankhurst needs Dinner Party added to their Wikidata. 651 items to add
# Emmeline Pethick-Lawrence needs Dinner Party added to their Wikidata. 650 items to add
# Emmy Noether needs Dinner Party added to their Wikidata. 649 items to add
# Enheduanna needs Dinner Party added to their Wikidata. 648 items to add
# Ende needs Dinner Party added to their Wikidata. 647 items to add
# Error encountered with Engleberga. Check manually. 646 items to review.
# Epicharis needs Dinner Party added to their Wikidata. 645 items to add
# Ereshkigal needs Dinner Party added to their Wikidata. 644 items to add
# Erinna needs Dinner Party added to their Wikidata. 643 items to add
# Esther needs Dinner Party added to their Wikidata. 642 items to add
# Error encountered with Etheldreda. Check manually. 641 items to review.
# Ethylwyn needs Dinner Party added to their Wikidata. 640 items to add
# Eugenia needs Dinner Party added to their Wikidata. 639 items to add
# Error encountered with Europa. Check manually. 638 items to review.
# Euryleon needs Dinner Party added to their Wikidata. 637 items to add
# Eurynome needs Dinner Party added to their Wikidata. 636 items to add
# Eurypyle needs Dinner Party added to their Wikidata. 635 items to add
# Eustochium needs Dinner Party added to their Wikidata. 634 items to add
# Eve needs Dinner Party added to their Wikidata. 633 items to add
# Error encountered with Failge. Check manually. 632 items to review.
# Error encountered with Fanny Burney. Check manually. 631 items to review.
# Fanny Mendelssohn needs Dinner Party added to their Wikidata. 630 items to add
# Faustina Bordoni needs Dinner Party added to their Wikidata. 629 items to add
# Fede Galizia needs Dinner Party added to their Wikidata. 628 items to add
# Federica Montseny needs Dinner Party added to their Wikidata. 627 items to add
# Fibors needs Dinner Party added to their Wikidata. 626 items to add
# Error encountered with Finola O'Donnel. Check manually. 625 items to review.
# Error encountered with Flavia Julia Helena. Check manually. 624 items to review.
# Florence Nightingale needs Dinner Party added to their Wikidata. 623 items to add
# Fortuna needs Dinner Party added to their Wikidata. 622 items to add
# Frances Brooke needs Dinner Party added to their Wikidata. 621 items to add
# Error encountered with Frances Harper. Check manually. 620 items to review.
# Frances Perkins needs Dinner Party added to their Wikidata. 619 items to add
# Frances Power Cobbe needs Dinner Party added to their Wikidata. 618 items to add
# Frances Willard needs Dinner Party added to their Wikidata. 617 items to add
# Frances Wright needs Dinner Party added to their Wikidata. 616 items to add
# Francesca Caccini needs Dinner Party added to their Wikidata. 615 items to add
# Error encountered with Francesca of Salerno. Check manually. 614 items to review.
# Francisca de Lebrija needs Dinner Party added to their Wikidata. 613 items to add
# Error encountered with Françoise de Maintenon. Check manually. 612 items to review.
# Error encountered with Frau Ava. Check manually. 611 items to review.
# Error encountered with Frau Cramer. Check manually. 610 items to review.
# Fredegund needs Dinner Party added to their Wikidata. 609 items to add
# Error encountered with Frederika Bremer. Check manually. 608 items to review.
# Error encountered with Freya. Check manually. 607 items to review.
# Frida Kahlo needs Dinner Party added to their Wikidata. 606 items to add
# Error encountered with Frija. Check manually. 605 items to review.
# Gabriela Mistral needs Dinner Party added to their Wikidata. 604 items to add
# Gabriele Münter needs Dinner Party added to their Wikidata. 603 items to add
# Gabrielle Petit needs Dinner Party added to their Wikidata. 602 items to add
# Error encountered with Gaia (mythology). Check manually. 601 items to review.
# Galla Placidia needs Dinner Party added to their Wikidata. 600 items to add
# Gaspara Stampa needs Dinner Party added to their Wikidata. 599 items to add
# Error encountered with Gebjon. Check manually. 598 items to review.
# Error encountered with Geillis Duncan. Check manually. 597 items to review.
# Genevieve d'Arconville needs Dinner Party added to their Wikidata. 596 items to add
# Genevieve needs Dinner Party added to their Wikidata. 595 items to add
# George Eliot needs Dinner Party added to their Wikidata. 594 items to add
# George Sand needs Dinner Party added to their Wikidata. 593 items to add
# Error encountered with Georgiana Cavendish. Check manually. 592 items to review.
# Germaine de Staël needs Dinner Party added to their Wikidata. 591 items to add
# Gertrude Käsebier needs Dinner Party added to their Wikidata. 590 items to add
# Gertrude of Hackeborn needs Dinner Party added to their Wikidata. 589 items to add
# Gertrude of Nivelles needs Dinner Party added to their Wikidata. 588 items to add
# Gertrude Stein needs Dinner Party added to their Wikidata. 587 items to add
# Error encountered with Gertrude Svensen. Check manually. 586 items to review.
# Gertrude the Great needs Dinner Party added to their Wikidata. 585 items to add
# Gisela of Kerzenbroeck needs Dinner Party added to their Wikidata. 584 items to add
# Gisela needs Dinner Party added to their Wikidata. 583 items to add
# Giustina Renier Michiel needs Dinner Party added to their Wikidata. 582 items to add
# Error encountered with Glueckel von Hameln. Check manually. 581 items to review.
# Golda Meir needs Dinner Party added to their Wikidata. 580 items to add
# Goody Glover needs Dinner Party added to their Wikidata. 579 items to add
# Gormlaith needs Dinner Party added to their Wikidata. 578 items to add
# Grace O'Malley needs Dinner Party added to their Wikidata. 577 items to add
# Error encountered with Gracia Mendesa. Check manually. 576 items to review.
# Guda needs Dinner Party added to their Wikidata. 575 items to add
# Error encountered with Guillemine. Check manually. 574 items to review.
# Gunda Beeg needs Dinner Party added to their Wikidata. 573 items to add
# Hannah Adams needs Dinner Party added to their Wikidata. 572 items to add
# Hannah Arendt needs Dinner Party added to their Wikidata. 571 items to add
# Error encountered with Hannah Crocker. Check manually. 570 items to review.
# Hannah Höch needs Dinner Party added to their Wikidata. 569 items to add
# Hannah More needs Dinner Party added to their Wikidata. 568 items to add
# Error encountered with Hannah Senesh. Check manually. 567 items to review.
# Hannah Woolley needs Dinner Party added to their Wikidata. 566 items to add
# Error encountered with Hannahanna. Check manually. 565 items to review.
# Harlind needs Dinner Party added to their Wikidata. 564 items to add
# Reinhild needs Dinner Party added to their Wikidata. 563 items to add
# Harriet Beecher Stowe needs Dinner Party added to their Wikidata. 562 items to add
# Harriet Hosmer needs Dinner Party added to their Wikidata. 561 items to add
# Harriet Martineau needs Dinner Party added to their Wikidata. 560 items to add
# Harriet Tubman needs Dinner Party added to their Wikidata. 559 items to add
# Hartense Lepaute needs Dinner Party added to their Wikidata. 558 items to add
# Error encountered with Hashop. Check manually. 557 items to review.
# Error encountered with Hasta Hansteen. Check manually. 556 items to review.
# Hathor needs Dinner Party added to their Wikidata. 555 items to add
# Error encountered with Hawisa. Check manually. 554 items to review.
# Hecate needs Dinner Party added to their Wikidata. 553 items to add
# Hecuba needs Dinner Party added to their Wikidata. 552 items to add
# Error encountered with Hedwig Nordenflycht. Check manually. 551 items to review.
# Hedwig needs Dinner Party added to their Wikidata. 550 items to add
# Error encountered with Hel (being). Check manually. 549 items to review.
# Error encountered with Helen Cornaro. Check manually. 548 items to review.
# Error encountered with Helen Diner. Check manually. 547 items to review.
# Helen Keller needs Dinner Party added to their Wikidata. 546 items to add
# Helen of Troy needs Dinner Party added to their Wikidata. 545 items to add
# Helena needs Dinner Party added to their Wikidata. 544 items to add
# Helena Blavatsky needs Dinner Party added to their Wikidata. 543 items to add
# Error encountered with Helene Kottauer. Check manually. 542 items to review.
# Héloïse needs Dinner Party added to their Wikidata. 541 items to add
# Henrietta Johnston needs Dinner Party added to their Wikidata. 540 items to add
# Henrietta Szold needs Dinner Party added to their Wikidata. 539 items to add
# Hera needs Dinner Party added to their Wikidata. 538 items to add
# Hermine Veres needs Dinner Party added to their Wikidata. 537 items to add
# Herrad of Landsberg needs Dinner Party added to their Wikidata. 536 items to add
# Error encountered with Hersend. Check manually. 535 items to review.
# Hersilia needs Dinner Party added to their Wikidata. 534 items to add
# Error encountered with Hester Stanhope. Check manually. 533 items to review.
# Hestiaea needs Dinner Party added to their Wikidata. 532 items to add
# Hiera needs Dinner Party added to their Wikidata. 531 items to add
# Hilda of Whitby needs Dinner Party added to their Wikidata. 530 items to add
# Hipparchia needs Dinner Party added to their Wikidata. 529 items to add
# Hippo needs Dinner Party added to their Wikidata. 528 items to add
# Error encountered with Hippolyte. Check manually. 527 items to review.
# Error encountered with Honorata Rodiana. Check manually. 526 items to review.
# Hortensia needs Dinner Party added to their Wikidata. 525 items to add
# Hortensia von Moos needs Dinner Party added to their Wikidata. 524 items to add
# Huldah needs Dinner Party added to their Wikidata. 523 items to add
# Hygeburg needs Dinner Party added to their Wikidata. 522 items to add
# Ida B. Wells needs Dinner Party added to their Wikidata. 521 items to add
# Error encountered with Ida Kaminska. Check manually. 520 items to review.
# Error encountered with Ida Pfeiffer. Check manually. 519 items to review.
# Ilmatar needs Dinner Party added to their Wikidata. 518 items to add
# Iltani needs Dinner Party added to their Wikidata. 517 items to add
# Ima Shalom needs Dinner Party added to their Wikidata. 516 items to add
# Imogen Cunningham needs Dinner Party added to their Wikidata. 515 items to add
# Inanna needs Dinner Party added to their Wikidata. 514 items to add
# Inessa Armand needs Dinner Party added to their Wikidata. 513 items to add
# Ingrida needs Dinner Party added to their Wikidata. 512 items to add
# Irène Joliot-Curie needs Dinner Party added to their Wikidata. 511 items to add
# Irene needs Dinner Party added to their Wikidata. 510 items to add
# Error encountered with Irkalla. Check manually. 509 items to review.
# Isabel de Guevara is a Dinner Party member. 508 items to add
# Isabel of France needs Dinner Party added to their Wikidata. 507 items to add
# Error encountered with Isabel Pinochet. Check manually. 506 items to review.
# Error encountered with Isabela Czartoryska. Check manually. 505 items to review.
# Isabella Andreini needs Dinner Party added to their Wikidata. 504 items to add
# Error encountered with Isabella Bird Bishop. Check manually. 503 items to review.
# Isabella Cortese needs Dinner Party added to their Wikidata. 502 items to add
# Error encountered with Isabella de Forz. Check manually. 501 items to review.
# Error encountered with Isabella de Joya Roseres. Check manually. 500 items to review.
# Error encountered with Isabella Losa. Check manually. 499 items to review.
# Isabella I of Castile needs Dinner Party added to their Wikidata. 498 items to add
# Error encountered with Isabella of Lorraine. Check manually. 497 items to review.
# Isadora Duncan needs Dinner Party added to their Wikidata. 496 items to add
# Error encountered with Isak Dinesen. Check manually. 495 items to review.
# Isis needs Dinner Party added to their Wikidata. 494 items to add
# Isotta Nogarola needs Dinner Party added to their Wikidata. 493 items to add
# Jacobe Felicie needs Dinner Party added to their Wikidata. 492 items to add
# Jadwiga needs Dinner Party added to their Wikidata. 491 items to add
# Jane Addams needs Dinner Party added to their Wikidata. 490 items to add
# Jane Anger needs Dinner Party added to their Wikidata. 489 items to add
# Jane Austen needs Dinner Party added to their Wikidata. 488 items to add
# Jane Harrison needs Dinner Party added to their Wikidata. 487 items to add
# Error encountered with Jane of Sutherland. Check manually. 486 items to review.
# Jane Weir needs Dinner Party added to their Wikidata. 485 items to add
# Error encountered with Jeanne Campan. Check manually. 484 items to review.
# Jeanne d'Albret needs Dinner Party added to their Wikidata. 483 items to add
# Error encountered with Jeanne de Montfort. Check manually. 482 items to review.
# Error encountered with Jeanne de Pompadour. Check manually. 481 items to review.
# Jeanne Dumée needs Dinner Party added to their Wikidata. 480 items to add
# Error encountered with Jeanne Louise Farrenc. Check manually. 479 items to review.
# Jeanne Mance needs Dinner Party added to their Wikidata. 478 items to add
# Error encountered with Jeanne Manon Roland. Check manually. 477 items to review.
# Error encountered with Jeanne Marie Guyon. Check manually. 476 items to review.
# Error encountered with Jeanne Recamier. Check manually. 475 items to review.
# Jeannette Rankin needs Dinner Party added to their Wikidata. 474 items to add
# Jenny Lind needs Dinner Party added to their Wikidata. 473 items to add
# Jezebel needs Dinner Party added to their Wikidata. 472 items to add
# Jeanne of Navarre needs Dinner Party added to their Wikidata. 471 items to add
# Joan of Arc needs Dinner Party added to their Wikidata. 470 items to add
# Joanna Baillie needs Dinner Party added to their Wikidata. 469 items to add
# Error encountered with Joanna Koerton. Check manually. 468 items to review.
# Joanna needs Dinner Party added to their Wikidata. 467 items to add
# Josefa Amar needs Dinner Party added to their Wikidata. 466 items to add
# Josefa Ortiz de Domínguez needs Dinner Party added to their Wikidata. 465 items to add
# Josephine Baker needs Dinner Party added to their Wikidata. 464 items to add
# Josephine Kablick needs Dinner Party added to their Wikidata. 463 items to add
# Jovita Idar needs Dinner Party added to their Wikidata. 462 items to add
# Judith Leyster needs Dinner Party added to their Wikidata. 461 items to add
# Judith Murray is a Dinner Party member. 460 items to add
# Julia Domma needs Dinner Party added to their Wikidata. 459 items to add
# Julia Maesa needs Dinner Party added to their Wikidata. 458 items to add
# Error encountered with Julia Mamaea. Check manually. 457 items to review.
# Julia Margaret Cameron needs Dinner Party added to their Wikidata. 456 items to add
# Julia Morgan needs Dinner Party added to their Wikidata. 455 items to add
# Error encountered with Juliana Bernes. Check manually. 454 items to review.
# Error encountered with Juliana of Norwich. Check manually. 453 items to review.
# Error encountered with Julie de Lespinasse. Check manually. 452 items to review.
# Juno needs Dinner Party added to their Wikidata. 451 items to add
# Error encountered with Justina Dietrich. Check manually. 450 items to review.
# Jutta needs Dinner Party added to their Wikidata. 449 items to add
# Error encountered with Kaahumanu. Check manually. 448 items to review.
# Error encountered with Kallirhoe Parren. Check manually. 447 items to review.
# Karen Horney needs Dinner Party added to their Wikidata. 446 items to add
# Error encountered with Karoline Pichler. Check manually. 445 items to review.
# Kate Campbell Hurd-Mead needs Dinner Party added to their Wikidata. 444 items to add
# Katharine Hepburn needs Dinner Party added to their Wikidata. 443 items to add
# Käthe Kollwitz needs Dinner Party added to their Wikidata. 442 items to add
# Käthe Schirmacher needs Dinner Party added to their Wikidata. 441 items to add
# Katherine Bethlen needs Dinner Party added to their Wikidata. 440 items to add
# Error encountered with Katherine Sheppard. Check manually. 439 items to review.
# Error encountered with Katti Moeler. Check manually. 438 items to review.
# Error encountered with Kenau Hasselaer. Check manually. 437 items to review.
# Khuwyt needs Dinner Party added to their Wikidata. 436 items to add
# Kora needs Dinner Party added to their Wikidata. 435 items to add
# Kubaba needs Dinner Party added to their Wikidata. 434 items to add
# Eleanor Butler (Ladies of Llangollen) needs Dinner Party added to their Wikidata. 433 items to add
# Sarah Ponsonby (Ladies of Llangollen) needs Dinner Party added to their Wikidata. 432 items to add
# Lady Beatrix needs Dinner Party added to their Wikidata. 431 items to add
# Lady Godiva needs Dinner Party added to their Wikidata. 430 items to add
# Margaret Beaufort (Lady) needs Dinner Party added to their Wikidata. 429 items to add
# Lady Uallach is a Dinner Party member. 428 items to add
# Lalla needs Dinner Party added to their Wikidata. 427 items to add
# La Malinche needs Dinner Party added to their Wikidata. 426 items to add
# Lamia needs Dinner Party added to their Wikidata. 425 items to add
# Lampedo needs Dinner Party added to their Wikidata. 424 items to add
# Error encountered with Las Huelgas. Check manually. 423 items to review.
# Laura Bassi needs Dinner Party added to their Wikidata. 422 items to add
# Laura Battiferri Ammanati needs Dinner Party added to their Wikidata. 421 items to add
# Laura Cereta needs Dinner Party added to their Wikidata. 420 items to add
# Laura Torres needs Dinner Party added to their Wikidata. 419 items to add
# Lavinia Fontana needs Dinner Party added to their Wikidata. 418 items to add
# Leah needs Dinner Party added to their Wikidata. 417 items to add
# Error encountered with Leonor d'Almeida. Check manually. 416 items to review.
# Error encountered with Leela of Granada. Check manually. 415 items to review.
# Leonora Baroni needs Dinner Party added to their Wikidata. 414 items to add
# Error encountered with Leontium. Check manually. 413 items to review.
# Leoparda needs Dinner Party added to their Wikidata. 412 items to add
# Error encountered with Levina Teerling. Check manually. 411 items to review.
# Error encountered with Liadain. Check manually. 410 items to review.
# Error encountered with Libana. Check manually. 409 items to review.
# Lili Boulanger needs Dinner Party added to their Wikidata. 408 items to add
# Lilith needs Dinner Party added to their Wikidata. 407 items to add
# Error encountered with Lilliard. Check manually. 406 items to review.
# Lioba needs Dinner Party added to their Wikidata. 405 items to add
# Error encountered with Livia Drusilla. Check manually. 404 items to review.
# Error encountered with Loretta. Check manually. 403 items to review.
# Lorraine Hansberry needs Dinner Party added to their Wikidata. 402 items to add
# Lou Andreas-Salomé needs Dinner Party added to their Wikidata. 401 items to add
# Louise Labé needs Dinner Party added to their Wikidata. 400 items to add
# Error encountered with Louise Le Gras. Check manually. 399 items to review.
# Louise Michel needs Dinner Party added to their Wikidata. 398 items to add
# Louise Nevelson needs Dinner Party added to their Wikidata. 397 items to add
# Error encountered with Louyse Bourgeois. Check manually. 396 items to review.
# Lucretia Marinelli needs Dinner Party added to their Wikidata. 395 items to add
# Lucretia Mott needs Dinner Party added to their Wikidata. 394 items to add
# Lucretia needs Dinner Party added to their Wikidata. 393 items to add
# Lucrezia Borgia needs Dinner Party added to their Wikidata. 392 items to add
# Lucrezia Tornabuoni needs Dinner Party added to their Wikidata. 391 items to add
# Lucy Stone needs Dinner Party added to their Wikidata. 390 items to add
# Error encountered with Luisa de Carvajal. Check manually. 389 items to review.
# Luisa Moreno needs Dinner Party added to their Wikidata. 388 items to add
# Error encountered with Luisa Roldan. Check manually. 387 items to review.
# Luise Gottsched needs Dinner Party added to their Wikidata. 386 items to add
# Error encountered with Luise Otto-Peter. Check manually. 385 items to review.
# Error encountered with Luiza Todi. Check manually. 384 items to review.
# Lydia needs Dinner Party added to their Wikidata. 383 items to add
# Lysistrata needs Dinner Party added to their Wikidata. 382 items to add
# Maacah needs Dinner Party added to their Wikidata. 381 items to add
# Mabel needs Dinner Party added to their Wikidata. 380 items to add
# Macha of the Red Tresses needs Dinner Party added to their Wikidata. 379 items to add
# Macha needs Dinner Party added to their Wikidata. 378 items to add
# Macrina needs Dinner Party added to their Wikidata. 377 items to add
# Maddalena Buonsignori needs Dinner Party added to their Wikidata. 376 items to add
# Error encountered with Madderakka. Check manually. 375 items to review.
# Error encountered with Madeleine de Demandolx. Check manually. 374 items to review.
# Error encountered with Madeleine de Sable. Check manually. 373 items to review.
# Madeleine de Scudéry needs Dinner Party added to their Wikidata. 372 items to add
# Magda Portal needs Dinner Party added to their Wikidata. 371 items to add
# Error encountered with Mahaut of Artois. Check manually. 370 items to review.
# Error encountered with Makeda. Check manually. 369 items to review.
# Error encountered with Mama Oclo. Check manually. 368 items to review.
# Manto needs Dinner Party added to their Wikidata. 367 items to add
# Margaret Brent needs Dinner Party added to their Wikidata. 366 items to add
# Error encountered with Margaret Cavendish. Check manually. 365 items to review.
# Margaret of Lincoln needs Dinner Party added to their Wikidata. 364 items to add
# Error encountered with Margaret Fell Fox. Check manually. 363 items to review.
# Margaret Fuller needs Dinner Party added to their Wikidata. 362 items to add
# Margaret Jones needs Dinner Party added to their Wikidata. 361 items to add
# Margaret Mead needs Dinner Party added to their Wikidata. 360 items to add
# Margaret Murray Washington needs Dinner Party added to their Wikidata. 359 items to add
# Margaret Murray needs Dinner Party added to their Wikidata. 358 items to add
# Error encountered with Margaret O'Connor. Check manually. 357 items to review.
# Margaret of Austria needs Dinner Party added to their Wikidata. 356 items to add
# Marguerite of Bourgogne needs Dinner Party added to their Wikidata. 355 items to add
# Error encountered with Margaret of Desmond. Check manually. 354 items to review.
# Margaret of Porète needs Dinner Party added to their Wikidata. 353 items to add
# Error encountered with Margaret of Scandinavia. Check manually. 352 items to review.
# ...
# Manual check required for: Coatlicue - URL: /wiki/Coatlicue
# Manual check required for: Cobhlair Mor - URL: /wiki/Cobhlair_Mor
# Manual check required for: Constance Lytton - URL: /wiki/Constance_Lytton
# Manual check required for: Corinna of Tanagra - URL: /wiki/Corinna_of_Tanagra
# Manual check required for: Cornelia - URL: /wiki/Cornelia_(wife_of_Paullus_Aemilius_Lepidus)
# Manual check required for: Cristina Trivulzio - URL: /wiki/Cristina_Trivulzio
# Manual check required for: Cunegund - URL: /wiki/Cunegund
# Manual check required for: Dervorguilla - URL: /wiki/Dervorguilla
# Manual check required for: Diemud - URL: /wiki/Diemud
# Manual check required for: Dorothea Leporin-Erxleben - URL: /wiki/Dorothea_Leporin-Erxleben
# Manual check required for: Dorothea von Rodde - URL: /wiki/Dorothea_von_Rodde
# Manual check required for: Douceline de Digne - URL: /wiki/Douceline_de_Digne
# Manual check required for: Eadburga - URL: /wiki/Eadburga
# Manual check required for: Egee - URL: /wiki/Egee
# Manual check required for: Elfrida Andree - URL: /wiki/Elfrida_Andree
# Manual check required for: Elisabeth de La Guerre - URL: /wiki/Elisabeth_de_La_Guerre
# Manual check required for: Élisabeth Vigée-Lebrun - URL: /wiki/Louise_%C3%89lisabeth_Vig%C3%A9e_Le_Brun
# Manual check required for: Eliza Lucas Pinckney - URL: /wiki/Eliza_Lucas_Pinckney
# Manual check required for: Elizabeth Bekker - URL: /wiki/Elizabeth_Bekker
# Manual check required for: Elizabeth Cheron - URL: /wiki/Elizabeth_Cheron
# Manual check required for: Elizabeth Danviers - URL: /wiki/Elizabeth_Danviers
# Manual check required for: Elizabeth Druzbacka - URL: /wiki/Elizabeth_Druzbacka
# Manual check required for: Elizabeth Hoby - URL: /wiki/Elizabeth_Hoby
# Manual check required for: Elizabeth Ney - URL: /wiki/Elizabeth_Ney
# Manual check required for: Elizabeth of Schönau - URL: /wiki/Elizabeth_of_Sch%C3%B6nau
# Manual check required for: Elizabeth Petrovna - URL: /wiki/Elizabeth_Petrovna
# Manual check required for: Elizabeth Southern - URL: /wiki/Elizabeth_Southern
# Manual check required for: Elizabeth Stagel - URL: /wiki/Elizabeth_Stagel
# Manual check required for: Ellen Richards - URL: /wiki/Ellen_Richards
# Manual check required for: Emilia Pardo-Bazán - URL: /wiki/Emilia_Pardo-Baz%C3%A1n
# Manual check required for: Emilie du Chatelet - URL: /wiki/Emilie_du_Chatelet
# Manual check required for: Engleberga - URL: /wiki/Engleberga
# Manual check required for: Etheldreda - URL: /wiki/Etheldreda
# Manual check required for: Europa - URL: /wiki/Europa_(mythology)
# Manual check required for: Failge - URL: /wiki/Margaret_O%27Connor
# Manual check required for: Fanny Burney - URL: /wiki/Fanny_Burney
# Manual check required for: Finola O'Donnel - URL: /wiki/Finola_O%27Donnel
# Manual check required for: Flavia Julia Helena - URL: /wiki/Flavia_Julia_Helena
# Manual check required for: Frances Harper - URL: /wiki/Frances_Harper
# Manual check required for: Francesca of Salerno - URL: /wiki/Francesca_of_Salerno
# Manual check required for: Françoise de Maintenon - URL: /wiki/Fran%C3%A7oise_de_Maintenon
# Manual check required for: Frau Ava - URL: /wiki/Frau_Ava
# Manual check required for: Frau Cramer - URL: /wiki/Frau_Cramer
# Manual check required for: Frederika Bremer - URL: /wiki/Frederika_Bremer
# Manual check required for: Freya - URL: /wiki/Freya
# Manual check required for: Frija - URL: /wiki/Frija
# Manual check required for: Gaia (mythology) - URL: /wiki/Gaia_(mythology)
# Manual check required for: Gebjon - URL: /wiki/Gebjon
# Manual check required for: Geillis Duncan - URL: /wiki/Gillis_Duncan
# Manual check required for: Georgiana Cavendish - URL: /wiki/Georgiana_Cavendish
# Manual check required for: Gertrude Svensen - URL: /wiki/Gertrude_Svensen
# Manual check required for: Glueckel von Hameln - URL: /wiki/Glueckel_von_Hameln
# Manual check required for: Gracia Mendesa - URL: /wiki/Gracia_Mendesa
# Manual check required for: Guillemine - URL: /wiki/Guillemine
# Manual check required for: Hannah Crocker - URL: /wiki/Hannah_Crocker
# Manual check required for: Hannah Senesh - URL: /wiki/Hannah_Senesh
# Manual check required for: Hannahanna - URL: /wiki/Hannahanna
# Manual check required for: Hashop - URL: /wiki/Hashop
# Manual check required for: Hasta Hansteen - URL: /wiki/Hasta_Hansteen
# Manual check required for: Hawisa - URL: /wiki/Hawise_of_Aumale
# Manual check required for: Hedwig Nordenflycht - URL: /wiki/Hedwig_Nordenflycht
# Manual check required for: Hel (being) - URL: /wiki/Hel_(being)
# Manual check required for: Helen Cornaro - URL: /wiki/Helen_Cornaro
# Manual check required for: Helen Diner - URL: /wiki/Helen_Diner
# Manual check required for: Helene Kottauer - URL: /wiki/Helene_Kottauer
# Manual check required for: Hersend - URL: /wiki/Hersend
# Manual check required for: Hester Stanhope - URL: /wiki/Hester_Stanhope
# Manual check required for: Hippolyte - URL: /wiki/Hippolyte
# Manual check required for: Honorata Rodiana - URL: /wiki/Honorata_Rodiana
# Manual check required for: Ida Kaminska - URL: /wiki/Ida_Kaminska
# Manual check required for: Ida Pfeiffer - URL: /wiki/Ida_Pfeiffer
# Manual check required for: Irkalla - URL: /wiki/Irkalla
# Manual check required for: Isabel Pinochet - URL: /wiki/Isabel_Pinochet
# Manual check required for: Isabela Czartoryska - URL: /wiki/Isabela_Czartoryska
# Manual check required for: Isabella Bird Bishop - URL: /wiki/Isabella_Bird_Bishop
# Manual check required for: Isabella de Forz - URL: /wiki/Isabella_de_Forz
# Manual check required for: Isabella de Joya Roseres - URL: /wiki/Isabella_de_Joya_Roseres
# Manual check required for: Isabella Losa - URL: /wiki/Isabella_Losa
# Manual check required for: Isabella of Lorraine - URL: /wiki/Isabella_of_Lorraine
# Manual check required for: Isak Dinesen - URL: /wiki/Isak_Dinesen
# Manual check required for: Jane of Sutherland - URL: /wiki/Jane_of_Sutherland
# Manual check required for: Jeanne Campan - URL: /wiki/Jeanne_Campan
# Manual check required for: Jeanne de Montfort - URL: /wiki/Jeanne_de_Montfort
# Manual check required for: Jeanne de Pompadour - URL: /wiki/Jeanne_de_Pompadour
# Manual check required for: Jeanne Louise Farrenc - URL: /wiki/Jeanne_Louise_Farrenc
# Manual check required for: Jeanne Manon Roland - URL: /wiki/Jeanne_Manon_Roland
# Manual check required for: Jeanne Marie Guyon - URL: /wiki/Jeanne_Marie_Guyon
# Manual check required for: Jeanne Recamier - URL: /wiki/Jeanne_Recamier
# Manual check required for: Joanna Koerton - URL: /wiki/Joanna_Koerton
# Manual check required for: Julia Mamaea - URL: /wiki/Julia_Mamaea
# Manual check required for: Juliana Bernes - URL: /wiki/Juliana_Bernes
# Manual check required for: Juliana of Norwich - URL: /wiki/Juliana_of_Norwich
# Manual check required for: Julie de Lespinasse - URL: /wiki/Julie_de_Lespinasse
# Manual check required for: Justina Dietrich - URL: /wiki/Justina_Dietrich
# Manual check required for: Kaahumanu - URL: /wiki/Kaahumanu
# Manual check required for: Kallirhoe Parren - URL: /wiki/Kallirhoe_Parren
# Manual check required for: Karoline Pichler - URL: /wiki/Karoline_Pichler
# Manual check required for: Katherine Sheppard - URL: /wiki/Katherine_Sheppard
# Manual check required for: Katti Moeler - URL: /wiki/Katti_Moeler
# Manual check required for: Kenau Hasselaer - URL: /wiki/Kenau_Hasselaer
# Manual check required for: Las Huelgas - URL: /wiki/Las_Huelgas
# Manual check required for: Leonor d'Almeida - URL: /wiki/Leonor_d%27Almeida
# Manual check required for: Leela of Granada - URL: /wiki/Leila:_or_The_Siege_of_Granada
# Manual check required for: Leontium - URL: /wiki/Leontium
# Manual check required for: Levina Teerling - URL: /wiki/Levina_Teerling
# Manual check required for: Liadain - URL: /wiki/Liadain
# Manual check required for: Libana - URL: /wiki/Libana
# Manual check required for: Lilliard - URL: /wiki/Lilliard
# Manual check required for: Livia Drusilla - URL: /wiki/Livia_Drusilla
# Manual check required for: Loretta - URL: /wiki/Loretta_de_Braose
# Manual check required for: Louise Le Gras - URL: /wiki/Louise_le_Gras
# Manual check required for: Louyse Bourgeois - URL: /wiki/Louyse_Bourgeois
# Manual check required for: Luisa de Carvajal - URL: /wiki/Luisa_de_Carvajal
# Manual check required for: Luisa Roldan - URL: /wiki/Luisa_Roldan
# Manual check required for: Luise Otto-Peter - URL: /wiki/Luise_Otto-Peter
# Manual check required for: Luiza Todi - URL: /wiki/Luiza_Todi
# Manual check required for: Madderakka - URL: /wiki/Madderakka
# Manual check required for: Madeleine de Demandolx - URL: /wiki/Madeleine_de_Demandolx
# Manual check required for: Madeleine de Sable - URL: /wiki/Madeleine_de_Sable
# Manual check required for: Mahaut of Artois - URL: /wiki/Mahaut_of_Artois
# Manual check required for: Makeda - URL: /wiki/Makeda
# Manual check required for: Mama Oclo - URL: /wiki/Mama_Oclo
# Manual check required for: Margaret Cavendish - URL: /wiki/Margaret_Cavendish
# Manual check required for: Margaret Fell Fox - URL: /wiki/Margaret_Fell_Fox
# Manual check required for: Margaret O'Connor - URL: /wiki/Margaret_O%27Connor
# Manual check required for: Margaret of Desmond - URL: /wiki/Margaret_FitzGerald,_Countess_of_Ormond
# Manual check required for: Margaret of Scandinavia - URL: /wiki/Margaret_of_Scandinavia
# Manual check required for: Margaret Paston - URL: /wiki/Margaret_Paston
# Manual check required for: Margaret Philipse - URL: /wiki/Margaret_Philipse
# Manual check required for: Margareta Karthauserin - URL: /wiki/Margareta_Karthauserin
# Manual check required for: Margarethe Dessoff - URL: /wiki/Margarethe_Dessoff
# Manual check required for: Margery Jourdemain - URL: /wiki/Margery_Jourdemayne,_%22the_Witch_of_Eye%22
# Manual check required for: Marguerita-Louise Couperin - URL: /wiki/Marguerita-Louise_Couperin
# Manual check required for: Maria Antonia Walpurgis - URL: /wiki/Maria_Antonia_Walpurgis_of_Bavaria
# Manual check required for: Maria de Agreda - URL: /wiki/Maria_de_Agreda
# Manual check required for: Maria de Coste Blanche - URL: /wiki/Maria_de_Coste_Blanche
# Manual check required for: Maria Kirch - URL: /wiki/Maria_Kirch
# Manual check required for: Maria Luisa Sanchez - URL: /wiki/Maria_Luisa_Sanchez
# Manual check required for: Maria Montoya Martinez - URL: /wiki/Maria_Montoya_Martinez
# Manual check required for: Maria Salvatori - URL: /wiki/Maria_Salvatori
# Manual check required for: Maria Stewart - URL: /wiki/Maria_Stewart
# Manual check required for: Marianna Alcoforado - URL: /wiki/Marianna_Alcoforado
# Manual check required for: Marie Bashkirtsev - URL: /wiki/Marie_Bashkirtsev
# Manual check required for: Marie Bovin - URL: /wiki/Marie_Bovin
# Manual check required for: Marie de l'Incarnation - URL: /wiki/Marie_de_l%27Incarnation
# Manual check required for: Marie de Lafayette - URL: /wiki/Marie_de_Lafayette
# Manual check required for: Marie de Sévigné - URL: /wiki/Marie_de_S%C3%A9vign%C3%A9
# Manual check required for: Marie du Deffand - URL: /wiki/Marie_du_Deffand
# Manual check required for: Marie Dugès - URL: /wiki/Marie_Jonet_Duges
# Manual check required for: Marie Geoffrin - URL: /wiki/Marie_Geoffrin
# Manual check required for: Marie LaChapelle - URL: /wiki/Marie_LaChapelle
# Manual check required for: Marie Lavoisier - URL: /wiki/Marie_Lavoisier
# Manual check required for: Maria Le Jars de Gournay - URL: /wiki/Marie_le_Jars_de_Gournay
# Manual check required for: Martha Baretskaya - URL: /wiki/Martha_Baretskaya
# Manual check required for: Martha of Bethany - URL: /wiki/Martha_of_Bethany
# Manual check required for: Martia Proba - URL: /wiki/Martia_Proba
# Manual check required for: Mary "Mother" Jones - URL: /wiki/Mary_%22Mother%22_Jones
# Manual check required for: Mary Müller - URL: /wiki/Mary_Ann_M%C3%BCller
# Manual check required for: Mary Ann Shadd Cary - URL: /wiki/Mary_Ann_Shadd_Cary
# Manual check required for: Mary Bonaventure - URL: /wiki/Mary_Bonaventure
# Manual check required for: Mary Goddard - URL: /wiki/Mary_Goddard
# Manual check required for: Mary Manley - URL: /wiki/Mary_Manley
# Manual check required for: Mary Monckton - URL: /wiki/Mary_Monckton
# Manual check required for: Mary Wortley Montagu - URL: /wiki/Mary_Wortley_Montagu
# Manual check required for: Mathilda of Germany - URL: /wiki/Mechthild_of_Germany
# Manual check required for: Mathilde of Tuscany - URL: /wiki/Mathilde_of_Tuscany
# Manual check required for: Meave - URL: /wiki/Meave
# Manual check required for: Milla Granson - URL: /wiki/Milla_Granson
# Manual check required for: Millicent Garrett Fawcett - URL: /wiki/Millicent_Garrett_Fawcett
# Manual check required for: Miranda Stuart - URL: /wiki/Miranda_Stuart
# Manual check required for: Modesta Pozzo - URL: /wiki/Modesta_Pozzo
# Manual check required for: Morrigan - URL: /wiki/Morrigan
# Manual check required for: Myrine - URL: /wiki/Myrine
# Manual check required for: Nanno - URL: /wiki/Nanno_(woman)
# Manual check required for: Naqi'a - URL: /wiki/Naqi%27a
# Manual check required for: Nicaula - URL: /wiki/Nicaula
# Manual check required for: Ninhursaga - URL: /wiki/Ninhursaga
# Manual check required for: Odilla - URL: /wiki/Odilla
# Manual check required for: Olympia Morata - URL: /wiki/Olympia_Morata
# Manual check required for: Omeciuatl - URL: /wiki/Omeciuatl
# Manual check required for: Pasiphae - URL: /wiki/Pasiphae
# Manual check required for: Perictyone - URL: /wiki/Perictyone
# Manual check required for: Phillipe Auguste - URL: /w/index.php?title=Phillipe_Auguste&action=edit&redlink=1
# Manual check required for: Plotina - URL: /wiki/Plotina
# Manual check required for: Praxagora - URL: /wiki/Praxagora
# Manual check required for: Puduhepa - URL: /wiki/Puduhepa
# Manual check required for: Rachel Katznelson - URL: /wiki/Rachel_Katznelson
# Manual check required for: Rachel Varnhagen - URL: /wiki/Rachel_Varnhagen
# Manual check required for: Rachel - URL: /wiki/Rashi%27s_daughters#Rachel_and_another_daughter
# Manual check required for: Rebekah - URL: /wiki/Rebekah
# Manual check required for: Rosalia of Palermo - URL: /wiki/Rosalia_of_Palermo
# Manual check required for: Saaredra Villanueva - URL: /wiki/Saaredra_Villanueva
# Manual check required for: Margaret - URL: /wiki/Saint_Margaret_of_Hungary
# Manual check required for: Paula - URL: /wiki/Saint_Paula
# Manual check required for: Salomée Halpir - URL: /wiki/Salom%C3%A9e_Halpir
# Manual check required for: Sarah Grimké - URL: /wiki/Sarah_Grimk%C3%A9
# Manual check required for: Sarah Jennings - URL: /wiki/Sarah_Jennings
# Manual check required for: Sarah Peale - URL: /wiki/Sarah_Peale
# Manual check required for: Shub-Ad of Ur - URL: /wiki/Shub-Ad_of_Ur
# Manual check required for: Sobeya - URL: /wiki/Sobeya
# Manual check required for: Sofia Kovalevskaya - URL: /wiki/Sofia_Kovalevskaya
# Manual check required for: Sophia Haydn - URL: /wiki/Sophia_Hayden_Bennett
# Manual check required for: Sophonisba Angussola - URL: /wiki/Sophonisba_Angussola
# Manual check required for: Sor Juana de la Cruz - URL: /wiki/Sor_Juana_de_la_Cruz
# Manual check required for: Stephanie de Genlis - URL: /wiki/Stephanie_de_Genlis
# Manual check required for: Susan la Flesche Piccotte - URL: /wiki/Susan_la_Flesche_Piccotte
# Manual check required for: Susanna Lorantffy - URL: /wiki/Susanna_Lorantffy
# Manual check required for: Suzanne Necker - URL: /wiki/Suzanne_Necker
# Manual check required for: Sylvia - URL: /wiki/Saint_Sylvia_of_Aquitaine
# Manual check required for: Tellus Mater - URL: /wiki/Tellus_Mater
# Manual check required for: The Furies - URL: /wiki/The_Furies
# Manual check required for: The Norns - URL: /wiki/The_Norns
# Manual check required for: Theoclea - URL: /wiki/Aristoclea
# Manual check required for: Theodora III - URL: /wiki/Theodora_Porphyrogenita_(11th_century)
# Manual check required for: Theodora II - URL: /wiki/Theodora_II
# Manual check required for: Theresa of Avila - URL: /wiki/Theresa_of_Avila
# Manual check required for: Tiy - URL: /wiki/Tiy
# Manual check required for: Virgin Mary - URL: /wiki/Virgin_Mary
# Manual check required for: Wetamoo - URL: /wiki/Wetamoo
# Manual check required for: Yekaterina Breshkovskaya - URL: /wiki/Yekaterina_Breshkovskaya
# Manual check required for: Yekaterina Dashkova - URL: /wiki/Yekaterina_Dashkova
# Manual check required for: Zoe - URL: /wiki/Zo%C3%AB_Porphyrogenita
